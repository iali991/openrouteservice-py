# %% [markdown]
# # Simple `openrouteservice-py` examples
#
# This notebook is just a small reference on how to use `openrouteservice` package to request:
# - [directions](https://openrouteservice.org/dev)
# - [isochrones](https://openrouteservice.org/dev/#/api-docs/v2/isochrones/{profile}/post)
# - [matrix](https://openrouteservice.org/dev/#/api-docs/v2/matrix/{profile}/post)
# - [POIs](https://openrouteservice.org/dev/#/api-docs/pois/post)
# - [Elevation](https://openrouteservice.org/dev/#/api-docs/elevation/line/post)
# - [Route Optimization](https://openrouteservice.org/dev/#/api-docs/optimization/post)

# %%
import openrouteservice as ors
import folium

client = ors.Client(key='5b3ce3597851110001cf62485a59fee9eaee45ca848c807ba6f97539')

# %% [markdown]
# ## TOC
#
# - **[Directions](#Directions)**
# - **[Isochrones](#Isochrones)**
# - **[Matrix](#Matrix)**
# - **[POIs](#POIs)**
# - **[Geocoding](#Geocoding)**
# - **[Elevation](#Elevation)**
# - **[Optimization](#Optimization)**

# %% [markdown]
# ## Directions

# %%
m = folium.Map(location=[52.521861, 13.40744], tiles='cartodbpositron', zoom_start=13)

# Some coordinates in Berlin
coordinates = [[13.42731, 52.51088], [13.384116, 52.533558]]

route = client.directions(
    coordinates=coordinates,
    profile='foot-walking',
    format='geojson',
    options={"avoid_features": ["steps"]},
    validate=False,
)
folium.PolyLine(locations=[list(reversed(coord)) 
                           for coord in 
                           route['features'][0]['geometry']['coordinates']]).add_to(m)
    
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_813fcf66e50ae3fea5093c24b37fbbea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_813fcf66e50ae3fea5093c24b37fbbea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_813fcf66e50ae3fea5093c24b37fbbea = L.map(
#                 &quot;map_813fcf66e50ae3fea5093c24b37fbbea&quot;,
#                 {
#                     center: [52.521861, 13.40744],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_650b7e656930a9a841f3f1961e07ed45 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_813fcf66e50ae3fea5093c24b37fbbea);
#
#
#             var poly_line_3ebde9569cc3d2c323e8247180324dd9 = L.polyline(
#                 [[52.511067, 13.426947], [52.511181, 13.426728], [52.511305, 13.426484], [52.5115, 13.426147], [52.511598, 13.426034], [52.511651, 13.426012], [52.511694, 13.426053], [52.511736, 13.426108], [52.511969, 13.426364], [52.511979, 13.426344], [52.512261, 13.425841], [52.512645, 13.425283], [52.512961, 13.424834], [52.513247, 13.424378], [52.513315, 13.424248], [52.51326, 13.424128], [52.513316, 13.423979], [52.513358, 13.423874], [52.513385, 13.423876], [52.513409, 13.42381], [52.513507, 13.423525], [52.513859, 13.422514], [52.513904, 13.422381], [52.513944, 13.422267], [52.514117, 13.42177], [52.514209, 13.421501], [52.514772, 13.419863], [52.514895, 13.419505], [52.514973, 13.419279], [52.515082, 13.41896], [52.515143, 13.418793], [52.515288, 13.418352], [52.515317, 13.418312], [52.515389, 13.418331], [52.51553, 13.418372], [52.515681, 13.41841], [52.515776, 13.418401], [52.516285, 13.418431], [52.516386, 13.418434], [52.516611, 13.418449], [52.517138, 13.418411], [52.517335, 13.418362], [52.517424, 13.41834], [52.517566, 13.4183], [52.518005, 13.418147], [52.518112, 13.418104], [52.518223, 13.418041], [52.518431, 13.417922], [52.518681, 13.417753], [52.518977, 13.417514], [52.519183, 13.417334], [52.519534, 13.417006], [52.519615, 13.416916], [52.520072, 13.416391], [52.520509, 13.415882], [52.520
],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: &quot;00ff00&quot;, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacit

# %% [markdown]
# ## Matrix

# %%
m = folium.Map(location=[52.521861, 13.40744], tiles='cartodbpositron', zoom_start=13)

# Some coordinates in Berlin
coordinates = [[13.384116, 52.533558], [13.428726, 52.519355], [13.41774, 52.498929], [13.374825, 52.496369]]

matrix = client.distance_matrix(
    locations=coordinates,
    profile='foot-walking',
    metrics=['distance', 'duration'],
    validate=False,
)

for marker in coordinates:
    folium.Marker(location=list(reversed(marker))).add_to(m)

print("Durations in secs: {}\n".format(matrix['durations']))
print("Distances in m: {}".format(matrix['distances']))

m
# Out:
# Durations in secs: [[0.0, 2754.05, 3795.19, 3660.45], [2754.05, 0.0, 1989.41, 4003.03], [3795.19, 1989.41, 0.0, 2467.21], [3660.45, 4003.03, 2467.21, 0.0]]
#
# Distances in m: [[0.0, 3825.17, 5271.25, 5084.1], [3825.17, 0.0, 2763.16, 5559.91], [5271.25, 2763.16, 0.0, 3426.76], [5084.1, 5559.91, 3426.76, 0.0]]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_09764289746834b5069957e1c521d58c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_09764289746834b5069957e1c521d58c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_09764289746834b5069957e1c521d58c = L.map(
#                 &quot;map_09764289746834b5069957e1c521d58c&quot;,
#                 {
#                     center: [52.521861, 13.40744],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_19f7d2441666fbfd0b416b85f11f450d = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_09764289746834b5069957e1c521d58c);
#
#
#             var marker_8c53851c5459444699c7ee7859f5f96d = L.marker(
#                 [52.533558, 13.384116],
#                 {}
#             ).addTo(map_09764289746834b5069957e1c521d58c);
#
#
#             var marker_289e57f707c7ecbbb2c82cfdf2cfc72c = L.marker(
#                 [52.519355, 13.428726],
#                 {}
#             ).addTo(map_09764289746834b5069957e1c521d58c);
#
#
#             var marker_dde3748f3078825308d828af7f88cb17 = L.marker(
#                 [52.498929, 13.41774],
#                 {}
#             ).addTo(map_09764289746834b5069957e1c521d58c);
#
#
#             var marker_0b72ef7f068ebde38d59ba3d674f14a7 = L.marker(
#                 [52.496369, 13.374825],
#                 {}
#             ).addTo(map_09764289746834b5069957e1c521d58c);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## POIs

# %%
m = folium.Map(location=[52.521861, 13.40744], tiles='cartodbpositron', zoom_start=13)

# Some coordinates in Berlin
geojson = {"type": "point", "coordinates": [13.384116, 52.533558]}

pois = client.places(
    request='pois',
    geojson=geojson,
    buffer=500,  # searches within 500 meters of specified point
    filter_category_ids=[561, 568],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
    validate=False,
#     dry_run=True
)

for poi in pois[0]['features']: 
    folium.Marker(
        location=list(reversed(poi['geometry']['coordinates'])),
        icon=folium.Icon(icon='info-sign'),
        popup=folium.Popup(poi['properties'].get('osm_tags', {}).get('name', "Bar ohne Namen")),
    ).add_to(m)
    
m
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15196\655337722.py in <module>
#      13 )
#      14
# ---> 15 for poi in pois[0]['features']:
#      16     folium.Marker(
#      17         location=list(reversed(poi['geometry']['coordinates'])),
#
# KeyError: 0

# %% [markdown]
# ## Geocoding

# %% [markdown]
# ### Forward Geocoding

# %%
m = folium.Map(location=[52.521861, 13.40744], tiles='cartodbpositron', zoom_start=13)

address = "Mollstraße 1, Berlin"

geocode = client.pelias_search(
    text=address,
    focus_point=list(reversed(m.location)),
    validate=False,
)

for result in geocode['features']:
    folium.Marker(
        location=list(reversed(result['geometry']['coordinates'])),
        icon=folium.Icon(icon='compass', color='green', prefix='fa'),
        popup=folium.Popup(result['properties']['name'])
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fcbf614cbc46bdb8e9b10775a7820f57 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fcbf614cbc46bdb8e9b10775a7820f57&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fcbf614cbc46bdb8e9b10775a7820f57 = L.map(
#                 &quot;map_fcbf614cbc46bdb8e9b10775a7820f57&quot;,
#                 {
#                     center: [52.521861, 13.40744],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_61a96e3e934534ce819a3fd32bbb57d5 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fcbf614cbc46bdb8e9b10775a7820f57);
#
#
#             var marker_d30eaa9d4d326b22d0d5fe9d3e033545 = L.marker(
#                 [52.526363, 13.415909],
#                 {}
#             ).addTo(map_fcbf614cbc46bdb8e9b10775a7820f57);
#
#
#             var icon_b8e357d7f7734225f8975997f4c4eefe = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;compass&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_d30eaa9d4d326b22d0d5fe9d3e033545.setIcon(icon_b8e357d7f7734225f8975997f4c4eefe);
#
#
#         var popup_f2471754c6cd2c79a955b36a4bbadbaa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_35006083cea8ce981739b97ffe7e694d = $(`&lt;div id=&quot;html_35006083cea8ce981739b97ffe7e694d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mollstraße 1&lt;/div&gt;`)[0];
#                 popup_f2471754c6cd2c79a955b36a4bbadbaa.setContent(html_35006083cea8ce981739b97ffe7e694d);
#
#
#
#         marker_d30eaa9d4d326b22d0d5fe9d3e033545.bindPopup(popup_f2471754c6cd2c79a955b36a4bbadbaa)
#         ;
#
#
#
#
#             var marker_f5de677610eb4d21e3aa18cb64f327e7 = L.marker(
#                 [52.526052, 13.416592],
#                 {}
#             ).addTo(map_fcbf614cbc46bdb8e9b10775a7820f57);
#
#
#             var icon_dbb51e21dcea8112750a178949247df1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;compass&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_f5de677610eb4d21e3aa18cb64f327e7.setIcon(icon_dbb51e21dcea8112750a178949247df1);
#
#
#         var popup_71ff68a55d446c320cea2952d9a1a326 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0076be31bcde51d5b81699387342350d = $(`&lt;div id=&quot;html_0076be31bcde51d5b81699387342350d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mollstraße 1a&lt;/div&gt;`)[0];
#                 popup_71ff68a55d446c320cea2952d9a1a326.setContent(html_0076be31bcde51d5b81699387342350d);
#
#
#
#         marker_f5de677610eb4d21e3aa18cb64f327e7.bindPopup(popup_71ff68a55d446c320cea2952d9a1a326)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Reverse Geocoding

# %%
m = folium.Map(location=[52.521861, 13.40744], tiles='cartodbpositron', zoom_start=13)

coordinate = [13.413448, 52.490993]

reverse = client.pelias_reverse(
    point=coordinate,
    validate=False,
)

for result in reverse['features']:
    folium.Marker(
        location=list(reversed(result['geometry']['coordinates'])),
        icon=folium.Icon(icon='history', color='green', prefix='fa'),
        popup=folium.Popup(result['properties']['label'])
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f520a0e59cde29714ce8ad69e6d38099 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f520a0e59cde29714ce8ad69e6d38099&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f520a0e59cde29714ce8ad69e6d38099 = L.map(
#                 &quot;map_f520a0e59cde29714ce8ad69e6d38099&quot;,
#                 {
#                     center: [52.521861, 13.40744],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_99524520b83faed8a05f50550ea617c4 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f520a0e59cde29714ce8ad69e6d38099);
#
#
#             var marker_88fdc601cdbde1dcbbe1462da38d357c = L.marker(
#                 [52.490985, 13.413364],
#                 {}
#             ).addTo(map_f520a0e59cde29714ce8ad69e6d38099);
#
#
#             var icon_c176b81ddb250dd1eee78285495febdb = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;history&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_88fdc601cdbde1dcbbe1462da38d357c.setIcon(icon_c176b81ddb250dd1eee78285495febdb);
#
#
#         var popup_05eeb10fdc28cf4bd5a78dfd9af1f5e9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e365ebb881412aa9ef8b5058d31c0a33 = $(`&lt;div id=&quot;html_e365ebb881412aa9ef8b5058d31c0a33&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Fichtestraße 32, Berlin, Germany&lt;/div&gt;`)[0];
#                 popup_05eeb10fdc28cf4bd5a78dfd9af1f5e9.setContent(html_e365ebb881412aa9ef8b5058d31c0a33);
#
#
#
#         marker_88fdc601cdbde1dcbbe1462da38d357c.bindPopup(popup_05eeb10fdc28cf4bd5a78dfd9af1f5e9)
#         ;
#
#
#
#
#             var marker_ae51cb63f1f76d587af6cfa62bbcb11a = L.marker(
#                 [52.490953, 13.41336],
#                 {}
#             ).addTo(map_f520a0e59cde29714ce8ad69e6d38099);
#
#
#             var icon_612faa36a82dd4ae29b4c853d90d8027 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;history&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_ae51cb63f1f76d587af6cfa62bbcb11a.setIcon(icon_612faa36a82dd4ae29b4c853d90d8027);
#
#
#         var popup_4ab6145f7478a2e064cf102e89aea225 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0c8d71b3842b26980b171c9432adddec = $(`&lt;div id=&quot;html_0c8d71b3842b26980b171c9432adddec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Medel, Berlin, Germany&lt;/div&gt;`)[0];
#                 popup_4ab6145f7478a2e064cf102e89aea225.setContent(html_0c8d71b3842b26980b171c9432adddec);
#
#
#
#         marker_ae51cb63f1f76d587af6cfa62bbcb11a.bindPopup(popup_4ab6145f7478a2e064cf102e89aea225)
#         ;
#
#
#
#
#             var marker_1743532187b43c6bd34d3820c01c12b6 = L.marker(
#                 [52.491129, 13.413336],
#                 {}
#             ).addTo(map_f520a0e59cde29714ce8ad69e6d38099);
#
#
#             var icon_3abe402fb129812045a70590c34ca235 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;history&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_1743532187b43c6bd34d3820c01c12b6.setIcon(icon_3abe402fb129812045a70590c34ca235);
#
#
#         var popup_bdb6fcd7494f7bfbbd0666b76307739f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_addff92f1ba8756e7f84ff5fbdbc4499 = $(`&lt;div id=&quot;html_addff92f1ba8756e7f84ff5fbdbc4499&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Fichtestraße 33, Berlin, Germany&lt;/div&gt;`)[0];
#                 popup_bdb6fcd7494f7bfbbd0666b76307739f.setContent(html_addff92f1ba8756e7f84ff5fbdbc4499);
#
#
#
#         marker_1743532187b43c6bd34d3820c01c12b6.bindPopup(popup_bdb6fcd7494f7bfbbd0666b76307739f)
#         ;
#
#
#
#
#             var marker_2822d7a7bfddc03565c5bfe087a7c6e8 = L.marker(
#                 [52.490815, 13.4134],
#                 {}
#             ).addTo(map_f520a0e59cde29714ce8ad69e6d38

# %% [markdown]
# ## Elevation

# %% [markdown]
# ### Point

# %%
coordinate = [13.384116, 52.533558]

elevation = client.elevation_point(
    format_in='point',
    format_out='point',
    geometry=coordinate
)

print(elevation['geometry'])
# Out:
# [13.384115999999999, 52.533558, 34.0]

# %% [markdown]
# ### Line

# %%
coordinates = [[13.384116, 52.533558], [13.428726, 52.519355], [13.41774, 52.498929], [13.374825, 52.496369]]

elevation = client.elevation_line(
    format_in='polyline',  # other options: geojson, encodedpolyline
    format_out='geojson',
    geometry=coordinates,
)

print(elevation['geometry']['coordinates'])
# Out:
# [[13.384116, 52.533558, 34], [13.428726, 52.519355, 40], [13.41774, 52.498929, 40], [13.374825, 52.496369, 39]]

# %% [markdown]
# ## Optimization

# %% [markdown]
# ### Simple waypoint optimization

# %% [markdown]
# With `openrouteservice-py` you can ask for waypoint optimization when requesting a normal `direction`. This assumes that your first coordinate is the start location and the last coordinate is the end location, i.e. only the `via` endpoints are optimized. To make it a round trip, make the first and last location the same.

# %%
m = folium.Map(location=[52.521861, 13.40744], tiles='cartodbpositron', zoom_start=13)

# Some coordinates in Berlin
coordinates = [[13.384116, 52.533558], [13.41774, 52.498929], [13.428726, 52.519355], [13.374825, 52.496369]]

# The popup will show the ID in the coordinate list. In a non-optimized waypoint order, the waypoints
# would have been visited from ID 0 to ID 3 sequentially.
for idx, coords in enumerate(coordinates):
    folium.Marker(location=list(reversed(coords)),
                 popup=folium.Popup("ID: {}".format(idx))).add_to(m)

route = client.directions(
    coordinates=coordinates,
    profile='foot-walking',
    format='geojson',
    validate=False,
    optimize_waypoints=True
)

folium.PolyLine(locations=[list(reversed(coord)) 
                           for coord in 
                           route['features'][0]['geometry']['coordinates']]).add_to(m)
    
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_24c66c4a430611f81f3a9f10da25463b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_24c66c4a430611f81f3a9f10da25463b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_24c66c4a430611f81f3a9f10da25463b = L.map(
#                 &quot;map_24c66c4a430611f81f3a9f10da25463b&quot;,
#                 {
#                     center: [52.521861, 13.40744],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_46a103d02953b2213bf0e229996abc7e = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_24c66c4a430611f81f3a9f10da25463b);
#
#
#             var marker_29fd44e8ed19bcca94c6f1b331c2bf45 = L.marker(
#                 [52.533558, 13.384116],
#                 {}
#             ).addTo(map_24c66c4a430611f81f3a9f10da25463b);
#
#
#         var popup_8c3e2b3e6c64aa25d3d20f8bed342e8e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_77cef75f406499e2b8d3775bfab93540 = $(`&lt;div id=&quot;html_77cef75f406499e2b8d3775bfab93540&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: 0&lt;/div&gt;`)[0];
#                 popup_8c3e2b3e6c64aa25d3d20f8bed342e8e.setContent(html_77cef75f406499e2b8d3775bfab93540);
#
#
#
#         marker_29fd44e8ed19bcca94c6f1b331c2bf45.bindPopup(popup_8c3e2b3e6c64aa25d3d20f8bed342e8e)
#         ;
#
#
#
#
#             var marker_18891d0d9f47f5e133aa3bda180cf48f = L.marker(
#                 [52.498929, 13.41774],
#                 {}
#             ).addTo(map_24c66c4a430611f81f3a9f10da25463b);
#
#
#         var popup_1a94ebe0d4e73bd0ac4dadc965d4f1d6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_17a3378973c6f08515a252a3f464f8ef = $(`&lt;div id=&quot;html_17a3378973c6f08515a252a3f464f8ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: 1&lt;/div&gt;`)[0];
#                 popup_1a94ebe0d4e73bd0ac4dadc965d4f1d6.setContent(html_17a3378973c6f08515a252a3f464f8ef);
#
#
#
#         marker_18891d0d9f47f5e133aa3bda180cf48f.bindPopup(popup_1a94ebe0d4e73bd0ac4dadc965d4f1d6)
#         ;
#
#
#
#
#             var marker_c05b5f96ce469ed981058ef1686081b0 = L.marker(
#                 [52.519355, 13.428726],
#                 {}
#             ).addTo(map_24c66c4a430611f81f3a9f10da25463b);
#
#
#         var popup_587c0f777f2c3d9c8bd1f95b785ac83b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f7530241fee2d134a0859356c250766c = $(`&lt;div id=&quot;html_f7530241fee2d134a0859356c250766c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: 2&lt;/div&gt;`)[0];
#                 popup_587c0f777f2c3d9c8bd1f95b785ac83b.setContent(html_f7530241fee2d134a0859356c250766c);
#
#
#
#         marker_c05b5f96ce469ed981058ef1686081b0.bindPopup(popup_587c0f777f2c3d9c8bd1f95b785ac83b)
#         ;
#
#
#
#
#             var marker_ef5f3aae73e07a36b353bc272af7c1b1 = L.marker(
#                 [52.496369, 13.374825],
#                 {}
#             ).addTo(map_24c66c4a430611f81f3a9f10da25463b);
#
#
#         var popup_f08f99ad727bcd0a121c91031be9d26d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3f198fb7bebcc482be90164c851b7bf4 = $(`&lt;div id=&quot;html_3f198fb7bebcc482be90164c851b7bf4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: 3&lt;/div&gt;`)[0];
#                 popup_f08f99ad727bcd0a121c91031be9d26d.setContent(html_3f198fb7bebcc482be90164c851b7bf4);
#
#
#
#         marker_ef5f3aae73e07a36b353bc272af7c1b1.bindPopup(popup_f08f99ad727bcd0a121c91031be9d26d)
#         ;
#
#
#
#
#             var poly_line_618070b570180ddba6efbdc53715b723 = L.polyline(
#                 [[52.533527, 13.384038], [52.533398, 13.384176], [52.532625, 13.385039], [52.532586, 13.385135], [52.532604, 13.385184], [52.532572, 13.385222], [52.532529, 13.38527], [52.532449, 13.38536], [52.532409, 13.385402], [52.532381, 13.385432], [52.532377, 13.385422], [52.532347, 13.385455], [52.531567, 13.386321], [52.531563, 13.386295], [52.531557, 13.386257], [52.531465, 13.386354], [52.531477, 13.386426], [52.531365, 13.386494], [52.531294, 13.386537], [52.531329, 13.386748], [52.531314, 13.386756], [52.531333, 13.386867], [52.531354, 13.386984], [52.531371, 13.386975], [52.531442, 13.387389], [52.53151, 13.388086], [52.531529, 13.388279], [52.531572, 13.388717], [52.531616, 13.38

# %% [markdown]
# ### Optimize job scheduling for multiple vehicles

# %% [markdown]
# The next example makes more use of the power of the ORS optimization endpoint. Two vehicles are assigned to 6 jobs, where the capacity constraints are such that each vehicle can only carry out 3 jobs on its route.

# %%
m = folium.Map(location=[52.521861, 13.40744], tiles='cartodbpositron', zoom_start=13)

vehicle_locations = [[13.390446, 52.506087], [13.384116, 52.533558]]
job_locations = [[13.428726, 52.519355],
                 [13.41774, 52.498929],
                 [13.374825, 52.496369],
                 [13.378859, 52.509796],
                 [13.400488, 52.509691],
                 [13.358517, 52.524264]]

# Assign vehicles to do the jobs
vehicles = []
for idx, coords in enumerate(vehicle_locations):
    vehicles.append(ors.optimization.Vehicle(
        id=idx,
        profile='driving-car',
        start=coords,
        end=coords,
        capacity=[3]  # Limit capacity so only 3 jobs can be taken by each vehicle
    ))
    folium.Marker(location=list(reversed(coords)), icon=folium.Icon(icon='truck', prefix='fa')).add_to(m)

# Define jobs to be carried out
jobs=[]
for idx, coords in enumerate(job_locations):
    jobs.append(ors.optimization.Job(
        id=idx,
        location=coords,
        amount=[1]  # Occupies capacity in vehicle
    ))
    folium.Marker(location=list(reversed(coords)), icon=folium.Icon(icon='archive', prefix='fa', color='green')).add_to(m)

optimized = client.optimization(
    jobs=jobs,
    vehicles=vehicles,
    geometry=True,  ## will output the geometry,
)

folium.PolyLine(
    locations=[list(reversed(coords)) for coords in ors.convert.decode_polyline(optimized['routes'][0]['geometry'])['coordinates']],
    color='red'
).add_to(m)

folium.PolyLine(
    locations=[list(reversed(coords)) for coords in ors.convert.decode_polyline(optimized['routes'][1]['geometry'])['coordinates']],
    color='orange'
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cfbb376111653fbfe9a69687d19eb6f4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cfbb376111653fbfe9a69687d19eb6f4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cfbb376111653fbfe9a69687d19eb6f4 = L.map(
#                 &quot;map_cfbb376111653fbfe9a69687d19eb6f4&quot;,
#                 {
#                     center: [52.521861, 13.40744],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b1d10819e8ff824b139924865397a47a = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_cfbb376111653fbfe9a69687d19eb6f4);
#
#
#             var marker_01123a126ac2da678f09e3fd7fff6024 = L.marker(
#                 [52.506087, 13.390446],
#                 {}
#             ).addTo(map_cfbb376111653fbfe9a69687d19eb6f4);
#
#
#             var icon_f8aa52926fb5e3d3aaddaa53d57424b5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;truck&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_01123a126ac2da678f09e3fd7fff6024.setIcon(icon_f8aa52926fb5e3d3aaddaa53d57424b5);
#
#
#             var marker_2b912270cf99ca0fb9f40c8c9176248e = L.marker(
#                 [52.533558, 13.384116],
#                 {}
#             ).addTo(map_cfbb376111653fbfe9a69687d19eb6f4);
#
#
#             var icon_b2e72943144cf8ecb30e5b3e0978ed5a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;truck&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_2b912270cf99ca0fb9f40c8c9176248e.setIcon(icon_b2e72943144cf8ecb30e5b3e0978ed5a);
#
#
#             var marker_1b7581bf2f3a7466ee1320c480f4cc14 = L.marker(
#                 [52.519355, 13.428726],
#                 {}
#             ).addTo(map_cfbb376111653fbfe9a69687d19eb6f4);
#
#
#             var icon_ebc627aae7d1f90991fed6b4c0a37a9f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;archive&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_1b7581bf2f3a7466ee1320c480f4cc14.setIcon(icon_ebc627aae7d1f90991fed6b4c0a37a9f);
#
#
#             var marker_e00e44ae9f38fbcd3600a6c5c040f3bc = L.marker(
#                 [52.498929, 13.41774],
#                 {}
#             ).addTo(map_cfbb376111653fbfe9a69687d19eb6f4);
#
#
#             var icon_330e28b78938c5baabe9cd8a0bcc5973 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;archive&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_e00e44ae9f38fbcd3600a6c5c040f3bc.setIcon(icon_330e28b78938c5baabe9cd8a0bcc5973);
#
#
#             var marker_b3cf99f65fc3a3cea965a56e8a12ad26 = L.marker(
#                 [52.496369, 13.374825],
#                 {}
#             ).addTo(map_cfbb376111653fbfe9a69687d19eb6f4);
#
#
#             var icon_c25e7d01ae3ee97c5de4da8821d636ed = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;archive&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_b3cf99f65fc3a3cea965a56e8a12ad26.setIcon(icon_c25e7d01ae3ee97c5de4da8821d636ed);
#
#
#             var marker_7e5f870958926dfb8464e48aadf839bb = L.marker(
#                 [52.509796, 13.378859],
#                 {}
#             ).addTo(map_cfbb376111653fbfe9a69687d19eb6f4);
#
#
#             var icon_fea981b8bb3f7e811c5e1f1507ef0db9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;archive&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_7e5f870958926dfb8464e48aadf839bb.setIcon(icon_fea981b8bb3f7e811c5e1f1507ef0db9);
#
#
#             var marker_d20caade9e6d45b95ec33d9102cc9a11 = L.marker(
#                 [52.509691,
